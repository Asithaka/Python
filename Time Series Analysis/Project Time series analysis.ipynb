# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv(r'G:\My Drive\My Data sets for modeling\USA_COVID-19_Total_deaths.csv')
df.head()
# Out:
#          date  cases  deaths
# 0  02/29/2020     70       1
# 1  03/01/2020     88       2
# 2  03/02/2020    104       3
# 3  03/03/2020    125       4
# 4  03/04/2020    161       2

# %%
df.shape
# Out:
# (349, 3)

# %%
df.drop(['cases'],axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# date      0
# deaths    0
# dtype: int64

# %%
df_tx=df.rename({'deaths':'Death_count'},axis=1)

df_tx['date']=pd.to_datetime(df_tx['date'])

df_tx.set_index('date',inplace=True)

df_tx.head()
# Out:
#             Death_count
# date
# 2020-02-29            1
# 2020-03-01            2
# 2020-03-02            3
# 2020-03-03            4
# 2020-03-04            2

# %%
df_tx.describe()
# Out:
#        Death_count
# count   349.000000
# mean   1361.673352
# std    1034.644798
# min       0.000000
# 25%     675.000000
# 50%    1082.000000
# 75%    1777.000000
# max    5116.000000

# %%
plt.figure(figsize=(16,8))

plt.plot(df_tx.Death_count)

plt.plot(df_tx.Death_count.rolling(7).mean())

plt.xlabel('Date')

plt.ylabel('Deaths')

plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

from pylab import rcParams

rcParams['figure.figsize']=16,10

result=seasonal_decompose(df_tx.Death_count.dropna(),model='additive')

result.plot()

plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

ADF_test=adfuller(df_tx.Death_count.dropna())

print ('ADF statistics: %f' %ADF_test[0])

print ('p-value: %f' %ADF_test[1])

print ('Critical values:')

for key,value in ADF_test[4].items():
    
    print('\t%s: %.4f'%(key,value))
# Out:
# ADF statistics: -1.916835
# p-value: 0.324183
# Critical values:
# 	1%: -3.4501
# 	5%: -2.8703
# 	10%: -2.5714

# %%
from statsmodels.tsa.stattools import kpss

kpss_test=kpss(df_tx.Death_count.dropna(),regression='c')

print ('ADF statistics: %f' %kpss_test[0])

print ('p-value: %f' %kpss_test[1])

print ('Critical values:')

for key,value in kpss_test[3].items():

    print('\t%s: %.4f'%(key,value))
# Out:
# ADF statistics: 0.889337
# p-value: 0.010000
# Critical values:
# 	10%: 0.3470
# 	5%: 0.4630
# 	2.5%: 0.5740
# 	1%: 0.7390

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

rcParams['figure.figsize']=16,4

plot_acf(df_tx.Death_count)

plot_pacf(df_tx.Death_count)

plt.show()

# %%
df_tx['first difference']=df_tx['Death_count']-df_tx['Death_count'].shift(1)

# %%
ADF_test=adfuller(df_tx['first difference'].dropna())

print ('ADF statistics: %f' %ADF_test[0])

print ('p-value: %f' %ADF_test[1])

print ('Critical values:')

for key,value in ADF_test[4].items():
    
    print('\t%s: %.4f'%(key,value))
# Out:
# ADF statistics: -3.951770
# p-value: 0.001685
# Critical values:
# 	1%: -3.4501
# 	5%: -2.8703
# 	10%: -2.5714

# %%
from statsmodels.tsa.stattools import kpss

kpss_test=kpss(df_tx['first difference'].dropna(),regression='c')

print ('ADF statistics: %f' %kpss_test[0])

print ('p-value: %f' %kpss_test[1])

print ('Critical values:')

for key,value in kpss_test[3].items():

    print('\t%s: %.4f'%(key,value))
# Out:
# ADF statistics: 0.067323
# p-value: 0.100000
# Critical values:
# 	10%: 0.3470
# 	5%: 0.4630
# 	2.5%: 0.5740
# 	1%: 0.7390

# %%
plot_acf(df_tx['first difference'].dropna())

plt.show()

plot_pacf(df_tx['first difference'].dropna())

plt.show()

# %%
df_tx['seasonal first difference']=df_tx['first difference']-df_tx['first difference'].shift(7)

# %%
df_tx['seasonal first difference'].plot(figsize=(16,4))

plt.show()

# %%
plot_acf(df_tx['seasonal first difference'].dropna())

plt.show()

plot_pacf(df_tx['seasonal first difference'].dropna())

plt.show()

# %%
import statsmodels.api as sm

# %%
model=sm.tsa.statespace.SARIMAX(df_tx['Death_count'].dropna(),
                                order=(0,1,2),
                                seasonal_order=(0,1,1,7)).fit()

# %%
print(model.summary())
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                         Death_count   No. Observations:                  349
# Model:             SARIMAX(0, 1, 2)x(0, 1, [1], 7)   Log Likelihood               -2449.292
# Date:                             Fri, 12 Feb 2021   AIC                           4906.584
# Time:                                     17:17:35   BIC                           4921.912
# Sample:                                 02-29-2020   HQIC                          4912.691
#                                       - 02-11-2021
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.4474      0.035    -12.608      0.000      -0.517      -0.378
# ma.L2         -0.2021      0.053     -3.801      0.000      -0.306      -0.098
# ma.S.L7       -0.6210      0.031    -20.251      0.000      -0.681      -0.561
# sigma2      1.005e+05   3685.949     27.257      0.000    9.32e+04    1.08e+05
# ===================================================================================
# Ljung-Box (Q):                       37.44   Jarque-Bera (JB):               703.73
# Prob(Q):                              0.59   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.97   Skew:                             0.23
# Prob(H) (two-sided):                  0.00   Kurtosis:                        10.02
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model.plot_diagnostics(figsize=(16,12))

plt.show()

# %%
import itertools

# %%
p=range(0,3)
d=range(0,2)
q=range(0,3)
pdq=list(itertools.product(p,d,q))

seasonal_pdq=list((x[0],x[1],x[2],7) for x in pdq)

for param in pdq:
    
    for seasonal_param in seasonal_pdq:
        
        try:
            model=sm.tsa.statespace.SARIMAX(df_tx['Death_count'],
                                            order=param,
                                            seasonal_order=seasonal_param)
            result=model.fit()
            print('SARIMA{}x{}7 - AIC:{}'.format(param,seasonal_param, result.aic.min()))
        
        except:
            continue
# Out:
# SARIMA(0, 0, 0)x(0, 0, 0, 7)7 - AIC:6188.203380610857
# SARIMA(0, 0, 0)x(0, 0, 1, 7)7 - AIC:5841.762493027014
# SARIMA(0, 0, 0)x(0, 0, 2, 7)7 - AIC:5606.342747832034
# SARIMA(0, 0, 0)x(0, 1, 0, 7)7 - AIC:5112.368501131363
# SARIMA(0, 0, 0)x(0, 1, 1, 7)7 - AIC:5113.128617339526
# SARIMA(0, 0, 0)x(0, 1, 2, 7)7 - AIC:5113.1325475841095
# SARIMA(0, 0, 0)x(1, 0, 0, 7)7 - AIC:5236.0231304083145
# SARIMA(0, 0, 0)x(1, 0, 1, 7)7 - AIC:5237.421572076006
# SARIMA(0, 0, 0)x(1, 0, 2, 7)7 - AIC:5236.475432460543
# SARIMA(0, 0, 0)x(1, 1, 0, 7)7 - AIC:5112.995373514872
# SARIMA(0, 0, 0)x(1, 1, 1, 7)7 - AIC:5112.734493373178
# SARIMA(0, 0, 0)x(1, 1, 2, 7)7 - AIC:5113.782187032872
# SARIMA(0, 0, 0)x(2, 0, 0, 7)7 - AIC:5237.292645630425
# SARIMA(0, 0, 0)x(2, 0, 1, 7)7 - AIC:5236.898428199948
# SARIMA(0, 0, 0)x(2, 0, 2, 7)7 - AIC:5237.280079914068
# SARIMA(0, 0, 0)x(2, 1, 0, 7)7 - AIC:5112.608767568921
# SARIMA(0, 0, 0)x(2, 1, 1, 7)7 - AIC:5114.056491630215
# SARIMA(0, 0, 0)x(2, 1, 2, 7)7 - AIC:5113.444511689384
# SARIMA(0, 0, 1)x(0, 0, 0, 7)7 - AIC:5819.026654525746
# SARIMA(0, 0, 1)x(0, 0, 1, 7)7 - AIC:5592.468269105357
# SARIMA(0, 0, 1)x(0, 0, 2, 7)7 - AIC:5446.382815306897
# SARIMA(0, 0, 1)x(0, 1, 0, 7)7 - AIC:5035.882585761708
# SARIMA(0, 0, 1)x(0, 1, 1, 7)7 - AIC:5022.373852028775
# SARIMA(0, 0, 1)x(0, 1, 2, 7)7 - AIC:5023.568815086783
# SARIMA(0, 0, 1)x(1, 0, 0, 7)7 - AIC:5151.692804696983
# SARIMA(0, 0, 1)x(1, 0, 1, 7)7 - AIC:5143.087621541487
# SARIMA(0, 0, 1)x(1, 0, 2, 7)7 - AIC:5182.060522929795
# SARIMA(0, 0, 1)x(1, 1, 0, 7)7 - AIC:5021.682577349024
# SARIMA(0, 0, 1)x(1, 1, 1, 7)7 - AIC:5023.664035944365
# SARIMA(0, 0, 1)x(1, 1, 2, 7)7 - AIC:5025.516614109921
# SARIMA(0, 0, 1)x(2, 0, 0, 7)7 - AIC:5140.438587826307
# SARIMA(0, 0, 1)x(2, 0, 2, 7)7 - AIC:5176.984206523089
# SARIMA(0, 0, 1)x(2, 1, 0, 7)7 - AIC:5023.661168038672
# SARIMA(0, 0, 1)x(2, 1, 1, 7)7 - AIC:5025.597775631645
# SARIMA(0, 0, 1)x(2, 1, 2, 7)7 - AIC:5025.667300960951
# SARIMA(0, 0, 2)x(0, 0, 0, 7)7 - AIC:5622.896288277561
# SARIMA(0, 0, 2)x(0, 0, 1, 7)7 - AIC:5461.487970055139
# SARIMA(0, 0, 2)x(0, 0, 2, 7)7 - AIC:5371.110035824568
# SARIMA(0, 0, 2)x(0, 1, 0, 7)7 - AIC:5019.1216855490875
# SARIMA(0, 0, 2)x(0, 1, 1, 7)7 - AIC:4992.309541856595
# SARIMA(0, 0, 2)x(0, 1, 2, 7)7 - AIC:4993.8312819188595
# SARIMA(0, 0, 2)x(1, 0, 0, 7)7 - AIC:5130.363281819746
# SARIMA(0, 0, 2)x(1, 0, 1, 7)7 - AIC:5474.173669438608
# SARIMA(0, 0, 2)x(1, 0, 2, 7)7 - AIC:5153.183957119758
# SARIMA(0, 0, 2)x(1, 1, 0, 7)7 - AIC:4993.041407089229
# SARIMA(0, 0, 2)x(1, 1, 1, 7)7 - AIC:4993.8345110977825
# SARIMA(0, 0, 2)x(1, 1, 2, 7)7 - AIC:4994.71042400961
# SARIMA(0, 0, 2)x(2, 0, 0, 7)7 - AIC:5108.307018412599
# SARIMA(0, 0, 2)x(2, 0, 2, 7)7 - AIC:5115.59349862095
# SARIMA(0, 0, 2)x(2, 1, 0, 7)7 - AIC:4993.828260306675
# SARIMA(0, 0, 2)x(2, 1, 1, 7)7 - AIC:4995.583305988817
# SARIMA(0, 0, 2)x(2, 1, 2, 7)7 - AIC:4995.333694390849
# SARIMA(0, 1, 0)x(0, 0, 0, 7)7 - AIC:5376.6550516439
# SARIMA(0, 1, 0)x(0, 0, 1, 7)7 - AIC:5251.857156615468
# SARIMA(0, 1, 0)x(0, 0, 2, 7)7 - AIC:5198.46162845089
# SARIMA(0, 1, 0)x(0, 1, 0, 7)7 - AIC:5074.953580039408
# SARIMA(0, 1, 0)x(0, 1, 1, 7)7 - AIC:4968.998462954965
# SARIMA(0, 1, 0)x(0, 1, 2, 7)7 - AIC:4969.772466789353
# SARIMA(0, 1, 0)x(1, 0, 0, 7)7 - AIC:5138.23163283557
# SARIMA(0, 1, 0)x(1, 0, 1, 7)7 - AIC:5076.604885101018
# SARIMA(0, 1, 0)x(1, 0, 2, 7)7 - AIC:5077.867353050029
# SARIMA(0, 1, 0)x(1, 1, 0, 7)7 - AIC:5008.02676109025
# SARIMA(0, 1, 0)x(1, 1, 1, 7)7 - AIC:4969.677064803851
# SARIMA(0, 1, 0)x(1, 1, 2, 7)7 - AIC:4972.874040002855
# SARIMA(0, 1, 0)x(2, 0, 0, 7)7 - AIC:5099.6703586776575
# SARIMA(0, 1, 0)x(2, 0, 1, 7)7 - AIC:5077.821111407151
# SARIMA(0, 1, 0)x(2, 0, 2, 7)7 - AIC:5079.729746278126
# SARIMA(0, 1, 0)x(2, 1, 0, 7)7 - AIC:4988.945335991932
# SARIMA(0, 1, 0)x(2, 1, 1, 7)7 - AIC:4971.504529904369
# SARIMA(0, 1, 0)x(2, 1, 2, 7)7 - AIC:4973.548298586624
# SARIMA(0, 1, 1)x(0, 0, 0, 7)7 - AIC:5371.975675117828
# SARIMA(0, 1, 1)x(0, 0, 1, 7)7 - AIC:5261.826297202233
# SARIMA(0, 1, 1)x(0, 0, 2, 7)7 - AIC:5175.582269047369
# SARIMA(0, 1, 1)x(0, 1, 0, 7)7 - AIC:5008.303701811195
# SARIMA(0, 1, 1)x(0, 1, 1, 7)7 - AIC:4919.876798926218
# SARIMA(0, 1, 1)x(0, 1, 2, 7)7 - AIC:4920.84189780811
# SARIMA(0, 1, 1)x(1, 0, 0, 7)7 - AIC:5088.5708615284975
# SARIMA(0, 1, 1)x(1, 0, 1, 7)7 - AIC:5029.8506806772275
# SARIMA(0, 1, 1)x(1, 0, 2, 7)7 - AIC:5031.7865075931395
# SARIMA(0, 1, 1)x(1, 1, 0, 7)7 - AIC:4948.870701910233
# SARIMA(0, 1, 1)x(1, 1, 1, 7)7 - AIC:4920.762452442071
# SARIMA(0, 1, 1)x(1, 1, 2, 7)7 - AIC:4923.914787793299
# SARIMA(0, 1, 1)x(2, 0, 0, 7)7 - AIC:5049.202614908354
# SARIMA(0, 1, 1)x(2, 0, 1, 7)7 - AIC:5061.802888920178
# SARIMA(0, 1, 1)x(2, 0, 2, 7)7 - AIC:5033.811396933661
# SARIMA(0, 1, 1)x(2, 1, 0, 7)7 - AIC:4937.100146496672
# SARIMA(0, 1, 1)x(2, 1, 1, 7)7 - AIC:4922.696839389695
# SARIMA(0, 1, 1)x(2, 1, 2, 7)7 - AIC:4924.693931379939
# SARIMA(0, 1, 2)x(0, 0, 0, 7)7 - AIC:5292.550100454134
# SARIMA(0, 1, 2)x(0, 0, 1, 7)7 - AIC:5177.559563658064
# SARIMA(0, 1, 2)x(0, 0, 2, 7)7 - AIC:5124.663455725826
# SARIMA(0, 1, 2)x(0, 1, 0, 7)7 - AIC:4998.080069892085
# SARIMA(0, 1, 2)x(0, 1, 1, 7)7 - AIC:4906.584349773971
# SARIMA(0, 1, 2)x(0, 1, 2, 7)7 - AIC:4907.090355933024
# SARIMA(0, 1, 2)x(1, 0, 0, 7)7 - AIC:5064.063609633466
# SARIMA(0, 1, 2)x(1, 0, 1, 7)7 - AIC:5013.414845329402
# SARIMA(0, 1, 2)x(1, 0, 2, 7)7 - AIC:5014.429612689057
# SARIMA(0, 1, 2)x(1, 1, 0, 7)7 - AIC:4938.714971566423
# SARIMA(0, 1, 2)x(1, 1, 1, 7)7 - AIC:4906.918404882089
# SARIMA(0, 1, 2)x(1, 1, 2, 7)7 - AIC:4910.616694357247
# SARIMA(0, 1, 2)x(2, 0, 0, 7)7 - AIC:5032.2335943783255
# SARIMA(0, 1, 2)x(2, 0, 1, 7)7 - AIC:5015.409656413194
# SARIMA(0, 1, 2)x(2, 0, 2, 7)7 - AIC:5017.093543595112
# SARIMA(0, 1, 2)x(2, 1, 0, 7)7 - AIC:4924.998719344205
# SARIMA(0, 1, 2)x(2, 1, 1, 7)7 - AIC:4908.674749128378
# SARIMA(0, 1, 2)x(2, 1, 2, 7)7 - AIC:4910.431565350602
# SARIMA(1, 0, 0)x(0, 0, 0, 7)7 - AIC:5388.85068033971
# SARIMA(1, 0, 0)x(0, 0, 1, 7)7 - AIC:5258.444204904066
# SARIMA(1, 0, 0)x(0, 0, 2, 7)7 - AIC:5200.717037177145
# SARIMA(1, 0, 0)x(0, 1, 0, 7)7 - AIC:5003.157256475638
# SARIMA(1, 0, 0)x(0, 1, 1, 7)7 - AIC:4945.298126551308
# SARIMA(1, 0, 0)x(0, 1, 2, 7)7 - AIC:4946.883030887732
# SARIMA(1, 0, 0)x(1, 0, 0, 7)7 - AIC:5104.982214607147
# SARIMA(1, 0, 0)x(1, 0, 1, 7)7 - AIC:5055.681422697558
# SARIMA(1, 0, 0)x(1, 0, 2, 7)7 - AIC:5057.555852534891
# SARIMA(1, 0, 0)x(1, 1, 0, 7)7 - AIC:4960.56039718504
# SARIMA(1, 0, 0)x(1, 1, 1, 7)7 - AIC:4946.825060828999
# SARIMA(1, 0, 0)x(1, 1, 2, 7)7 - AIC:4949.342730672684
# SARIMA(1, 0, 0)x(2, 0, 0, 7)7 - AIC:5067.384172864693
# SARIMA(1, 0, 0)x(2, 0, 1, 7)7 - AIC:5057.5475044089735
# SARIMA(1, 0, 0)x(2, 0, 2, 7)7 - AIC:5059.153101277187
# SARIMA(1, 0, 0)x(2, 1, 0, 7)7 - AIC:4953.051806743577
# SARIMA(1, 0, 0)x(2, 1, 1, 7)7 - AIC:4948.3744612372375
# SARIMA(1, 0, 0)x(2, 1, 2, 7)7 - AIC:4950.710034873512
# SARIMA(1, 0, 1)x(0, 0, 0, 7)7 - AIC:5380.891396085597
# SARIMA(1, 0, 1)x(0, 0, 1, 7)7 - AIC:5260.399498539815
# SARIMA(1, 0, 1)x(0, 0, 2, 7)7 - AIC:5193.472628418945
# SARIMA(1, 0, 1)x(0, 1, 0, 7)7 - AIC:4997.077357619854
# SARIMA(1, 0, 1)x(0, 1, 1, 7)7 - AIC:4925.1693127550225
# SARIMA(1, 0, 1)x(0, 1, 2, 7)7 - AIC:4926.32274698715
# SARIMA(1, 0, 1)x(1, 0, 0, 7)7 - AIC:5091.835869805156
# SARIMA(1, 0, 1)x(1, 0, 1, 7)7 - AIC:5037.044514012429
# SARIMA(1, 0, 1)x(1, 0, 2, 7)7 - AIC:5038.6183205527805
# SARIMA(1, 0, 1)x(1, 1, 0, 7)7 - AIC:4947.583161878141
# SARIMA(1, 0, 1)x(1, 1, 1, 7)7 - AIC:4926.242291179821
# SARIMA(1, 0, 1)x(1, 1, 2, 7)7 - AIC:4929.09847606656
# SARIMA(1, 0, 1)x(2, 0, 0, 7)7 - AIC:5052.537452852908
# SARIMA(1, 0, 1)x(2, 0, 1, 7)7 - AIC:5038.591930936636
# SARIMA(1, 0, 1)x(2, 0, 2, 7)7 - AIC:5042.959615761956
# SARIMA(1, 0, 1)x(2, 1, 0, 7)7 - AIC:4938.275539514141
# SARIMA(1, 0, 1)x(2, 1, 1, 7)7 - AIC:4928.107127614135
# SARIMA(1, 0, 1)x(2, 1, 2, 7)7 - AIC:4929.010759201962
# SARIMA(1, 0, 2)x(0, 0, 0, 7)7 - AIC:5312.5086824557075
# SARIMA(1, 0, 2)x(0, 0, 1, 7)7 - AIC:5199.041260683249
# SARIMA(1, 0, 2)x(0, 0, 2, 7)7 - AIC:5146.83724824664
# SARIMA(1, 0, 2)x(0, 1, 0, 7)7 - AIC:4997.6012318643925
# SARIMA(1, 0, 2)x(0, 1, 1, 7)7 - AIC:4916.420879655493
# SARIMA(1, 0, 2)x(0, 1, 2, 7)7 - AIC:4917.215807568692
# SARIMA(1, 0, 2)x(1, 0, 0, 7)7 - AIC:5080.923598429802
# SARIMA(1, 0, 2)x(1, 0, 1, 7)7 - AIC:5026.792079866707
# SARIMA(1, 0, 2)x(1, 0, 2, 7)7 - AIC:5036.375269820424
# SARIMA(1, 0, 2)x(1, 1, 0, 7)7 - AIC:4943.874215446539
# SARIMA(1, 0, 2)x(1, 1, 1, 7)7 - AIC:4917.066508190954
# SARIMA(1, 0, 2)x(1, 1, 2, 7)7 - AIC:4920.466609088629
# SARIMA(1, 0, 2)x(2, 0, 0, 7)7 - AIC:5044.647305265227
# SARIMA(1, 0, 2)x(2, 0, 1, 7)7 - AIC:5029.068031928329
# SARIMA(1, 0, 2)x(2, 0, 2, 7)7 - AIC:5041.864720655228
# SARIMA(1, 0, 2)x(2, 1, 0, 7)7 - AIC:4932.240292471197
# SARIMA(1, 0, 2)x(2, 1, 1, 7)7 - AIC:4918.765034840827
# SARIMA(1, 0, 2)x(2, 1, 2, 7)7 - AIC:4920.871845162116
# SARIMA(1, 1, 0)x(0, 0, 0, 7)7 - AIC:5375.084108662602
# SARIMA(1, 1, 0)x(0, 0, 1, 7)7 - AIC:5253.201878009628
# SARIMA(1, 1, 0)x(0, 0, 2, 7)7 - AIC:5193.546274059714
# SARIMA(1, 1, 0)x(0, 1, 0, 7)7 - AIC:5037.9278094942965
# SARIMA(1, 1, 0)x(0, 1, 1, 7)7 - AIC:4943.635758454042
# SARIMA(1, 1, 0)x(0, 1, 2, 7)7 - AIC:4944.546678334677
# SARIMA(1, 1, 0)x(1, 0, 0, 7)7 - AIC:5115.044298900327
# SARIMA(1, 1, 0)x(1, 0, 1, 7)7 - AIC:5053.132770343587
# SARIMA(1, 1, 0)x(1, 0, 2, 7)7 - AIC:5054.444983568705
# SARIMA(1, 1, 0)x(1, 1, 0, 7)7 - AIC:4976.237395713219
# SARIMA(1, 1, 0)x(1, 1, 1, 7)7 - AIC:4944.477403634382
# SARIMA(1, 1, 0)x(1, 1, 2, 7)7 - AIC:4947.661283530726
# SARIMA(1, 1, 0)x(2, 0, 0, 7)7 - AIC:5074.652104189789
# SARIMA(1, 1, 0)x(2, 0, 1, 7)7 - AIC:5054.415638099716
# SARIMA(1, 1, 0)x(2, 0, 2, 7)7 - AIC:5057.1173613311
# SARIMA(1, 1, 0)x(2, 1, 0, 7)7 - AIC:4961.520472067937
# SARIMA(1, 1, 0)x(2, 1, 1, 7)7 - AIC:4946.413502372489
# SARIMA(1, 1, 0)x(2, 1, 2, 7)7 - AIC:4948.29340162255
# SARIMA(1, 1, 1)x(0, 0, 0, 7)7 - AIC:5326.673862304097
# SARIMA(1, 1, 1)x(0, 0, 1, 7)7 - AIC:5187.86221832638
# SARIMA(1, 1, 1)x(0, 0, 2, 7)7 - AIC:5125.296984625814
# SARIMA(1, 1, 1)x(0, 1, 0, 7)7 - AIC:4991.971258134146
# SARIMA(1, 1, 1)x(0, 1, 1, 7)7 - AIC:4905.8586765880345
# SARIMA(1, 1, 1)x(0, 1, 2, 7)7 - AIC:4906.097390627492
# SARIMA(1, 1, 1)x(1, 0, 0, 7)7 - AIC:5076.317656173802
# SARIMA(1, 1, 1)x(1, 0, 1, 7)7 - AIC:5012.029197922546
# SARIMA(1, 1, 1)x(1, 0, 2, 7)7 - AIC:5012.966562859121
# SARIMA(1, 1, 1)x(1, 1, 0, 7)7 - AIC:4937.485607228706
# SARIMA(1, 1, 1)x(1, 1, 1, 7)7 - AIC:4905.863526179622
# SARIMA(1, 1, 1)x(1, 1, 2, 7)7 - AIC:4909.862405361895
# SARIMA(1, 1, 1)x(2, 0, 0, 7)7 - AIC:5046.534097596434
# SARIMA(1, 1, 1)x(2, 0, 2, 7)7 - AIC:5016.093264932675
# SARIMA(1, 1, 1)x(2, 1, 0, 7)7 - AIC:4923.986416687598
# SARIMA(1, 1, 1)x(2, 1, 1, 7)7 - AIC:4907.536521230503
# SARIMA(1, 1, 1)x(2, 1, 2, 7)7 - AIC:4909.510453249209
# SARIMA(1, 1, 2)x(0, 0, 0, 7)7 - AIC:5286.02064783408
# SARIMA(1, 1, 2)x(0, 0, 1, 7)7 - AIC:5173.039216739579
# SARIMA(1, 1, 2)x(0, 0, 2, 7)7 - AIC:5121.46943685847
# SARIMA(1, 1, 2)x(0, 1, 0, 7)7 - AIC:4988.450136463471
# SARIMA(1, 1, 2)x(0, 1, 1, 7)7 - AIC:4907.491347129673
# SARIMA(1, 1, 2)x(0, 1, 2, 7)7 - AIC:4907.775564127893
# SARIMA(1, 1, 2)x(1, 0, 0, 7)7 - AIC:5059.953507304951
# SARIMA(1, 1, 2)x(1, 0, 1, 7)7 - AIC:5013.616020385719
# SARIMA(1, 1, 2)x(1, 0, 2, 7)7 - AIC:5022.987553604825
# SARIMA(1, 1, 2)x(1, 1, 0, 7)7 - AIC:4939.482228769022
# SARIMA(1, 1, 2)x(1, 1, 1, 7)7 - AIC:4907.551440142134
# SARIMA(1, 1, 2)x(1, 1, 2, 7)7 - AIC:4911.487701455046
# SARIMA(1, 1, 2)x(2, 0, 0, 7)7 - AIC:5031.067065142477
# SARIMA(1, 1, 2)x(2, 0, 1, 7)7 - AIC:5022.938653583951
# SARIMA(1, 1, 2)x(2, 0, 2, 7)7 - AIC:5024.972125394252
# SARIMA(1, 1, 2)x(2, 1, 0, 7)7 - AIC:4925.837801842906
# SARIMA(1, 1, 2)x(2, 1, 1, 7)7 - AIC:4909.228875434117
# SARIMA(1, 1, 2)x(2, 1, 2, 7)7 - AIC:4911.2166223253025
# SARIMA(2, 0, 0)x(0, 0, 0, 7)7 - AIC:5385.036156202527
# SARIMA(2, 0, 0)x(0, 0, 1, 7)7 - AIC:5260.418704852333
# SARIMA(2, 0, 0)x(0, 0, 2, 7)7 - AIC:5198.955437359307
# SARIMA(2, 0, 0)x(0, 1, 0, 7)7 - AIC:4999.802885678144
# SARIMA(2, 0, 0)x(0, 1, 1, 7)7 - AIC:4934.493644519473
# SARIMA(2, 0, 0)x(0, 1, 2, 7)7 - AIC:4935.851653604121
# SARIMA(2, 0, 0)x(1, 0, 0, 7)7 - AIC:5098.680660870281
# SARIMA(2, 0, 0)x(1, 0, 1, 7)7 - AIC:5045.445030359207
# SARIMA(2, 0, 0)x(1, 0, 2, 7)7 - AIC:5047.1755591381425
# SARIMA(2, 0, 0)x(1, 1, 0, 7)7 - AIC:4953.416584385456
# SARIMA(2, 0, 0)x(1, 1, 1, 7)7 - AIC:4935.781670654814
# SARIMA(2, 0, 0)x(1, 1, 2, 7)7 - AIC:4938.396942183876
# SARIMA(2, 0, 0)x(2, 0, 0, 7)7 - AIC:5059.14721809223
# SARIMA(2, 0, 0)x(2, 0, 1, 7)7 - AIC:5082.034462767397
# SARIMA(2, 0, 0)x(2, 0, 2, 7)7 - AIC:5056.429346379841
# SARIMA(2, 0, 0)x(2, 1, 0, 7)7 - AIC:4944.990251676029
# SARIMA(2, 0, 0)x(2, 1, 1, 7)7 - AIC:4937.5483493374495
# SARIMA(2, 0, 0)x(2, 1, 2, 7)7 - AIC:4938.451159483677
# SARIMA(2, 0, 1)x(0, 0, 0, 7)7 - AIC:5378.95983448727
# SARIMA(2, 0, 1)x(0, 0, 1, 7)7 - AIC:5262.262356510743
# SARIMA(2, 0, 1)x(0, 0, 2, 7)7 - AIC:5204.1411156910735
# SARIMA(2, 0, 1)x(0, 1, 0, 7)7 - AIC:4997.796914658334
# SARIMA(2, 0, 1)x(0, 1, 1, 7)7 - AIC:4916.082793304347
# SARIMA(2, 0, 1)x(0, 1, 2, 7)7 - AIC:4916.691647875721
# SARIMA(2, 0, 1)x(1, 0, 0, 7)7 - AIC:5079.823655219705
# SARIMA(2, 0, 1)x(1, 0, 1, 7)7 - AIC:5058.078820344277
# SARIMA(2, 0, 1)x(1, 0, 2, 7)7 - AIC:5037.943743951226
# SARIMA(2, 0, 1)x(1, 1, 0, 7)7 - AIC:4943.758205512884
# SARIMA(2, 0, 1)x(1, 1, 1, 7)7 - AIC:4916.500182164071
# SARIMA(2, 0, 1)x(1, 1, 2, 7)7 - AIC:4920.04511231025
# SARIMA(2, 0, 1)x(2, 0, 0, 7)7 - AIC:5066.721699010877
# SARIMA(2, 0, 1)x(2, 0, 1, 7)7 - AIC:5059.598938597215
# SARIMA(2, 0, 1)x(2, 0, 2, 7)7 - AIC:5062.386110376795
# SARIMA(2, 0, 1)x(2, 1, 0, 7)7 - AIC:4931.9835708091305
# SARIMA(2, 0, 1)x(2, 1, 1, 7)7 - AIC:4918.13027900122
# SARIMA(2, 0, 1)x(2, 1, 2, 7)7 - AIC:4919.087747004945
# SARIMA(2, 0, 2)x(0, 0, 0, 7)7 - AIC:5306.847373354514
# SARIMA(2, 0, 2)x(0, 0, 1, 7)7 - AIC:5192.815590888449
# SARIMA(2, 0, 2)x(0, 0, 2, 7)7 - AIC:5157.038859621178
# SARIMA(2, 0, 2)x(0, 1, 0, 7)7 - AIC:4999.471160990491
# SARIMA(2, 0, 2)x(0, 1, 1, 7)7 - AIC:4917.690693729604
# SARIMA(2, 0, 2)x(0, 1, 2, 7)7 - AIC:4918.333515868738
# SARIMA(2, 0, 2)x(1, 0, 0, 7)7 - AIC:5098.202290464509
# SARIMA(2, 0, 2)x(1, 0, 1, 7)7 - AIC:5039.696410933969
# SARIMA(2, 0, 2)x(1, 0, 2, 7)7 - AIC:5044.2603644465
# SARIMA(2, 0, 2)x(1, 1, 0, 7)7 - AIC:4945.592978194438
# SARIMA(2, 0, 2)x(1, 1, 1, 7)7 - AIC:4918.148624436306
# SARIMA(2, 0, 2)x(1, 1, 2, 7)7 - AIC:4921.747885474278
# SARIMA(2, 0, 2)x(2, 0, 0, 7)7 - AIC:5057.570497271342
# SARIMA(2, 0, 2)x(2, 0, 1, 7)7 - AIC:5055.756321410557
# SARIMA(2, 0, 2)x(2, 0, 2, 7)7 - AIC:5051.625086294105
# SARIMA(2, 0, 2)x(2, 1, 0, 7)7 - AIC:4933.715407596516
# SARIMA(2, 0, 2)x(2, 1, 1, 7)7 - AIC:4921.8529450007645
# SARIMA(2, 0, 2)x(2, 1, 2, 7)7 - AIC:4921.610987508202
# SARIMA(2, 1, 0)x(0, 0, 0, 7)7 - AIC:5348.852468831442
# SARIMA(2, 1, 0)x(0, 0, 1, 7)7 - AIC:5238.4276494933565
# SARIMA(2, 1, 0)x(0, 0, 2, 7)7 - AIC:5183.459276934584
# SARIMA(2, 1, 0)x(0, 1, 0, 7)7 - AIC:5020.209840938791
# SARIMA(2, 1, 0)x(0, 1, 1, 7)7 - AIC:4931.126598604778
# SARIMA(2, 1, 0)x(0, 1, 2, 7)7 - AIC:4932.04209130777
# SARIMA(2, 1, 0)x(1, 0, 0, 7)7 - AIC:5101.146925191071
# SARIMA(2, 1, 0)x(1, 0, 1, 7)7 - AIC:5041.181546175933
# SARIMA(2, 1, 0)x(1, 0, 2, 7)7 - AIC:5042.446004180877
# SARIMA(2, 1, 0)x(1, 1, 0, 7)7 - AIC:4961.3422595793745
# SARIMA(2, 1, 0)x(1, 1, 1, 7)7 - AIC:4931.977851616604
# SARIMA(2, 1, 0)x(1, 1, 2, 7)7 - AIC:4934.972268166006
# SARIMA(2, 1, 0)x(2, 0, 0, 7)7 - AIC:5061.762963168891
# SARIMA(2, 1, 0)x(2, 0, 1, 7)7 - AIC:5079.318020516927
# SARIMA(2, 1, 0)x(2, 0, 2, 7)7 - AIC:5045.1503685900225
# SARIMA(2, 1, 0)x(2, 1, 0, 7)7 - AIC:4947.881066218882
# SARIMA(2, 1, 0)x(2, 1, 1, 7)7 - AIC:4933.93744299362
# SARIMA(2, 1, 0)x(2, 1, 2, 7)7 - AIC:4935.801221756507
# SARIMA(2, 1, 1)x(0, 0, 0, 7)7 - AIC:5252.890606933655
# SARIMA(2, 1, 1)x(0, 0, 1, 7)7 - AIC:5159.958197129935
# SARIMA(2, 1, 1)x(0, 0, 2, 7)7 - AIC:5116.591720824992
# SARIMA(2, 1, 1)x(0, 1, 0, 7)7 - AIC:4991.736026503511
# SARIMA(2, 1, 1)x(0, 1, 1, 7)7 - AIC:4907.341885022954
# SARIMA(2, 1, 1)x(0, 1, 2, 7)7 - AIC:4907.654867700365
# SARIMA(2, 1, 1)x(1, 0, 0, 7)7 - AIC:5059.947007676954
# SARIMA(2, 1, 1)x(1, 0, 1, 7)7 - AIC:5028.525549895578
# SARIMA(2, 1, 1)x(1, 0, 2, 7)7 - AIC:5014.311373444139
# SARIMA(2, 1, 1)x(1, 1, 0, 7)7 - AIC:4939.48208450786
# SARIMA(2, 1, 1)x(1, 1, 1, 7)7 - AIC:4907.435446783702
# SARIMA(2, 1, 1)x(1, 1, 2, 7)7 - AIC:4911.353098325124
# SARIMA(2, 1, 1)x(2, 0, 0, 7)7 - AIC:5031.055005611668
# SARIMA(2, 1, 1)x(2, 0, 1, 7)7 - AIC:5043.669654509575
# SARIMA(2, 1, 1)x(2, 0, 2, 7)7 - AIC:5018.196146485286
# SARIMA(2, 1, 1)x(2, 1, 0, 7)7 - AIC:4925.805790639224
# SARIMA(2, 1, 1)x(2, 1, 1, 7)7 - AIC:4909.112574684108
# SARIMA(2, 1, 1)x(2, 1, 2, 7)7 - AIC:4911.10243062156
# SARIMA(2, 1, 2)x(0, 0, 0, 7)7 - AIC:5166.654967071102
# SARIMA(2, 1, 2)x(0, 0, 1, 7)7 - AIC:5132.406500989481
# SARIMA(2, 1, 2)x(0, 0, 2, 7)7 - AIC:5096.365486353987
# SARIMA(2, 1, 2)x(0, 1, 0, 7)7 - AIC:4992.742723129816
# SARIMA(2, 1, 2)x(0, 1, 1, 7)7 - AIC:4905.615019019407
# SARIMA(2, 1, 2)x(0, 1, 2, 7)7 - AIC:4910.076278356461
# SARIMA(2, 1, 2)x(1, 0, 0, 7)7 - AIC:5060.318770557513
# SARIMA(2, 1, 2)x(1, 0, 1, 7)7 - AIC:5011.4715868766925
# SARIMA(2, 1, 2)x(1, 0, 2, 7)7 - AIC:5017.005049793386
# SARIMA(2, 1, 2)x(1, 1, 0, 7)7 - AIC:4940.739963632045
# SARIMA(2, 1, 2)x(1, 1, 1, 7)7 - AIC:4907.437665752488
# SARIMA(2, 1, 2)x(1, 1, 2, 7)7 - AIC:4914.600939874395
# SARIMA(2, 1, 2)x(2, 0, 0, 7)7 - AIC:5032.508343317361
# SARIMA(2, 1, 2)x(2, 0, 1, 7)7 - AIC:5013.045465453962
# SARIMA(2, 1, 2)x(2, 0, 2, 7)7 - AIC:5015.800231281189
# SARIMA(2, 1, 2)x(2, 1, 0, 7)7 - AIC:4925.536183735441
# SARIMA(2, 1, 2)x(2, 1, 1, 7)7 - AIC:4911.487424363591
# SARIMA(2, 1, 2)x(2, 1, 2, 7)7 - AIC:4913.519882890236

# %%
y=df_tx['Death_count']
y_train = y[:'2020-10-01'] 
y_test = y['2020-10-02':]

# %%
ax = y.plot(label='actual',figsize=(16,6))

predict = model.get_prediction(start='2020-10-02', dynamic=False)

predict_ci = predict.conf_int()

y_forecast = predict.predicted_mean

y_forecast.plot(ax=ax, label='forecast', alpha=.8,color='r')

ax.fill_between(predict_ci.index,predict_ci.iloc[:, 0],
                predict_ci.iloc[:, 1], color='k', alpha=.1)

ax.set_xlabel('Date')

ax.set_ylabel('Death count')

plt.legend()

plt.show()
